425013783289, -1.024279869575043, 1.1613287802717305, 0.758168342858836, 0.16992980058893248, 0.4448958837750938, 1.0360586011598718, -1.0352338424941077, 0.32897501233978926, -1.3922029628241452, -1.2297663415741424, -1.3673358699166214, -1.0851023350101698, 0.12314561928001042, 1.228730496622187, -0.23706771230544071, -0.2772617392123646, 0.6086645146372974, -0.07123005020126878, -1.120519949339806, -0.2219248494359493, 0.9798528586619946, -0.6617956932060848, -0.24813598207805568, 0.8580707739135855, 0.3270025337071464, -0.8229915800630405, 0.3140198041974342, 0.5868668714306624, -1.0010070033229261, -1.2344130545744596, 1.0212501580955207, 1.204658894929079, -0.8532837691248455, -1.3115634747624494, -1.115345679314544, 1.203305995682464, -1.3780966553773806, 0.27733013510369503, 1.194022452730276, -1.3993536131227282, 0.6551513344732182, -0.3513119735126205, 0.6667438156943366, -0.8415606321384356, -0.6879929218774482, -0.008113835554077466, -0.009999507901389542, 1.7 ...

# %% [markdown]
# # Precision, recall, f1 and support from sklearn
#
# * **precision:**
#     * out of all examples classified as positive, how many truly were? <br>
#     * **minimize false positives** <br>
#     * certain that what you classified as positive, really is <br>
#     * $\frac{tp}{tp+fp}$
#     * spam detection
# <br>
# <br>
# * **recall:**
#     * out of all true examples of the class, how many were classified as being so? <br>
#     * **minimize false negatives** <br>
#     * certain that you got all/most of positive cases <br>
#     * $\frac{tp}{tp+fn}$
#     * cancer detection, fraud detection

# %%
yt = np.array(['cat', 'dog', 'pig', 'cat', 'dog', 'pig'])
yp = np.array(['cat', 'pig', 'dog', 'cat', 'cat', 'dog'])

# %%
precision_recall_fscore_support(yt, yp)
# Out:
# (array([ 0.66666667,  0.        ,  0.        ]),
#  array([ 1.,  0.,  0.]),
#  array([ 0.8,  0. ,  0. ]),
#  array([2, 2, 2], dtype=int64))

# %%
precision_recall_fscore_support(yt, yp, average='weighted')
# Out:
# (0.22222222222222221, 0.33333333333333331, 0.26666666666666666, None)

# %%
yt = np.array([1, 0, 1, 0, 1, 0, 1, 0])
yp = np.array([1, 1, 1, 1, 1, 1, 0, 0])

# %%
precision_recall_fscore_support(yt, yp)
# Out:
# (array([ 0.5,  0.5]),
#  array([ 0.25,  0.75]),
#  array([ 0.33333333,  0.6       ]),
#  array([4, 4], dtype=int64))

# %%
precision_recall_fscore_support(yt, yp, average='weighted')
# Out:
# (0.5, 0.5, 0.46666666666666667, None)

# %%
precision_recall_fscore_support(yt, yp, average='binary')
# Out:
# (0.5, 0.75, 0.59999999999999998, None)

# %%
confusion_matrix(yt, yp)
# Out:
# array([[1, 3],
#        [1, 3]], dtype=int64)

# %% [markdown]
# ### Confusion matrix multiclass
# * rows = ytrue
# * cols = ypred

# %%
y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
confusion_matrix(y_true, y_pred, labels=["ant", "bird", "cat"])
# Out:
# array([[2, 0, 0],
#        [0, 0, 1],
#        [1, 0, 2]], dtype=int64)

# %%
confusion_matrix(y_true, y_pred, labels=["ant", "cat", "bird"])
# Out:
# array([[2, 0, 0],
#        [1, 2, 0],
#        [0, 1, 0]], dtype=int64)
